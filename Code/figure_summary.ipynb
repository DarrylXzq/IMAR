# %%
import pandas as pd
import matplotlib.pyplot as plt
from typing import Dict

# %%
plt.rcParams['font.size'] = 9
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Times New Roman'


def plot_model_performance(csv_files: Dict[str, str]):
    plt.figure(figsize=(10, 4))
    for model_name, csv_file in csv_files.items():
        data = pd.read_csv(csv_file)
        plt.plot(data['val_loss'], label=f'{model_name}')
    # plt.title('Inception Validation Loss Over Epochs', fontweight='normal')
    plt.xlabel('Epoch', fontweight='normal')
    plt.ylabel('Validation Loss', fontweight='normal')
    plt.legend()
    # plt.ylim(0, 0.7)
    # plt.ylim(0, 0.5)
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(10, 4))
    for model_name, csv_file in csv_files.items():
        data = pd.read_csv(csv_file)
        plt.plot(data['val_accuracy'], label=f'{model_name}')
    # plt.title('Inception Validation Accuracy Over Epochs', fontweight='normal')
    plt.xlabel('Epoch', fontweight='normal')
    plt.ylabel('Validation Accuracy', fontweight='normal')
    plt.legend()
    # plt.ylim(0.2, 1.02)
    # plt.ylim(0.5, 1.02)
    plt.grid(True)
    plt.show()

# %%
csv_files = {
    # 'VGG16_Flatten': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\vgg16_model.csv',
    # 'InceptionV3_Flatten': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\InceptionV3_model.csv',
    # 'ResNet50_Flatten': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\ResNet50_model.csv',
    # 'MobileNet_Flatten': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\MobileNet_model.csv',
    # 'IMAR': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\ensemble.csv',
    # 'No Attention IMAR': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\ensemble_no_attention.csv'
    # 'IAR': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_inception\IAR.csv',
    # 'MAR': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_mobile\MAR.csv',

    # 'VGG16_GlobalAveragePooling': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\vgg16_model_GAP.csv',
    #     'InceptionV3_GlobalAveragePooling': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\InceptionV3_model_GAP.csv',
    #     'ResNet50_GlobalAveragePooling': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\ResNet50_model_GAP.csv',
    #     'MobileNet_GlobalAveragePooling': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\MobileNet_model_GAP.csv',

    # 'SRIM': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\ensemble.csv',
    # 'IRA': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_inception\inception_with_Res_attention.csv',
    # 'MRA': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_mobile\mobile_with_Res_attention.csv',

    # 'vgg16 7:1.5:1.5' : r'D:\Download\MV_Coursework\Coursework\Code\dataset_split\vgg16.csv',
    # 'vgg16 8:1:1' : r'D:\Download\MV_Coursework\Coursework\Code\dataset_split\vgg16_8_1_1.csv',

    # 'No Augmented' : r'D:\Download\MV_Coursework\Coursework\Code\dataset_split\vgg16.csv',
    # 'RGB Augmented' : r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\RGB_augmented_250_224.csv',
    # 'Mix Augmented' : r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\Mixed_augmented_250_224.csv',

    # 'RGB Augmented 250': r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\RGB_augmented_250_224.csv',
    # 'RGB Augmented 300': r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\RGB_augmented_300_224.csv'

    # 'custom loss and acc 1.5:1.5:1' : r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\custom_loss_acc.csv',
    # 'custom loss and acc 2:2:1' : r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\custom_loss_acc_1_1_1.csv',

    # 'No custom' : r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\Nocustomer_loss_acc.csv',
    # 'custom 1.5:1.5:1' : r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\custom_loss_acc_1.5_1.5_1.csv',
    # 'custom 1.75:1.75:1' : r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\custom_loss_acc_1.75_1.75_1.csv',
    # 'custom 2:2:1' : r'D:\Download\MV_Coursework\Coursework\Code\augmented_image\custom_loss_acc_2_2_1.csv',

    # 'Improved Inception' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_inception\inception.csv',
    # 'Improved Inception + Residual' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_inception\inception_with_Res.csv',
    # 'Improved Inception + Residual + Attention' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_inception\inception_with_Res_attention.csv',

    # 'Improved MobileNet' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_mobile\mobile.csv',
    # 'Improved MobileNet + Residual' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_mobile\mobile_with_Res.csv',
    # 'Improved MobileNet + Residual + Attention' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_mobile\mobile_with_Res_attention.csv'

    'IMAR': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\ensemble.csv',
    'VGG16' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\vgg16_model.csv',
    'InceptionV3' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\InceptionV3_model.csv',
    'MobileNet' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\MobileNet_model.csv',
    'ResNet50' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_pretrain\ResNet50_model.csv',

    # 'batch 16 learning rate 0.000025' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_inception\inception_with_Res_attention.csv',
    # 'batch 32 learning rate 0.001' : r'D:\Download\MV_Coursework\Coursework\Code\figure\no_optimize_parameter\inception_test1.csv',
    # 'batch 32 learning rate 0.0001' : r'D:\Download\MV_Coursework\Coursework\Code\figure\no_optimize_parameter\inception_test2.csv',

    # 'batch 16 learning rate 0.000025' : r'D:\Download\MV_Coursework\Coursework\Code\figure\new_structure_mobile\mobile_with_Res_attention.csv',
    # 'batch 64 learning rate 0.0001' : r'D:\Download\MV_Coursework\Coursework\Code\figure\no_optimize_parameter\mobile_test1.csv',
    # 'batch 32 learning rate 0.0001' : r'D:\Download\MV_Coursework\Coursework\Code\figure\no_optimize_parameter\mobile_test2.csv',
    
    # 'IMAR Non-Augmented': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\ensemble_7_1.5_1.5.csv',
    # 'IMAR RGB 300': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\Mixed_augmented_300_224.csv',
    # 'IMAR RGB 200': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\Mixed_augmented_200_224.csv',
    # 'IMAR MIX 300': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\RGB_augmented_300_224.csv',
    # 'IMAR MIX 200': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\RGB_augmented_200_224.csv',

    # 'IMAR 60%:20%:20%': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\ensemble_6_2_2.csv',
    # 'IMAR 70%:15%:15%': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\ensemble_7_1.5_1.5.csv',
    # 'IMAR 80%:10%:10%': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\ensemble_8_1_1.csv',
    
    # 'Non-custom-weight': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\RGB_augmented_300_224.csv',
    # 'Custom Weight 1.5:1.5:1': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\custom_1.5_1.5_1.csv',
    # 'Custom Weight 1.75:1.75:1': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\custom_1.75_1.75_1.csv',
    # 'Custom Weight 2:2:1': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\custom_2_2_1.csv',
    # 'Custom Weight 2.25:2.25:1': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\custom_2.25_2.25_1.csv',
    # 'Custom Weight 2.5:2.5:1': r'D:\Download\MV_Coursework\Coursework\Code\figure\new_ensemble\custom_2.5_2.5_1.csv',
}

# %%
plot_model_performance(csv_files)
